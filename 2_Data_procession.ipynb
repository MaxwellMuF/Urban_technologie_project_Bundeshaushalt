# %% [markdown]
# ## Goal:
# Show the development of government expenditure / revenue over 10 years.
#
# ## Issues:
# 1. no unique index/identifier.
# 2. Title, chapter and individual plan (col: "Tit.", "Kap.", "Epl.") are together unique, but not constant (consistent) over the years.
# 3. Names of bookings (col: "Zweckbestimmung") are also not constant.
#
# Summarized: It is impossible to track all entries (rows) over 10 years, the number of rows per year varies. But as many entries as possible should be mapped.
#
# ## Solutions:
# 1. Make a new id column from col: Tit., chap., epl..
# 2. Try to include the purpose or other columns. In the next chapter, this is attempted via embeddings of an encoder.
# 3. In this notebook at least the problem is identified: e.g. the entry “Arbeitslosengeld II” changes the name as well as the Kap. and Tit. over the years.
#
# One approach would be to manually create a mapper dict (10 largest bookings are roughly 50% of the budget).
# Instead, an NLP approach is used in the next notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
#import requests
#import txtai

# %% [markdown]
# # Functions

# %%
def drop_nan(df):
    col_ist = [col for col in df.columns if col.startswith("Ist")][0]
    df = df.dropna(subset=col_ist, ignore_index=True)
    df = df[df[col_ist] > 1000]
    df[["Epl.", "Kap.", "Tit."]] = df[["Epl.", "Kap.", "Tit."]].astype(int, copy=False)
    df = df[["Epl.", "Kap.", "Tit.", col_ist, "Zweckbestimmung"]]
    return df

# %%
def make_id_col(df):
    df["id"] = df["Tit."].astype(str).str.zfill(5) + df["Epl."].astype(str).str.zfill(2) + df["Kap."].astype(str).str.zfill(2)
    df = df.drop(["Epl.", "Kap.", "Tit."], axis=1)
    return df

# %%
def pipeline(range_years):
    df_result = pd.read_excel(f"data/HR20{range_years[0]}.xlsx")
    df_result = make_id_col(drop_nan(df_result))[["id", "Zweckbestimmung", f"Ist 20{range_years[0]}"]]
    for year in range(range_years[0]+1, range_years[1]):
        df_i = pd.read_excel(f"data/HR20{year}.xlsx")
        df_i = drop_nan(df_i)
        df_i = make_id_col(df_i).drop("Zweckbestimmung", axis=1)
        df_result = pd.merge(df_result, df_i, on='id', how="inner")
    return df_result

# %%
df_test = pd.read_excel("data/data_raw/HR2012.xlsx")
df_test_2 = pd.read_excel("data/data_raw/HR2022.xlsx")

# %% [markdown]
# # First Look at Data

# %%
df_test
# Out:
#       Epl.  Kap.   Tit.   Fkt. Flex.  Tgr.  E/A  \
# 0      1.0   NaN    NaN    NaN   NaN   NaN  NaN
# 1      1.0   1.0    NaN    NaN   NaN   NaN  NaN
# 2      NaN   NaN    NaN    NaN   NaN   NaN  NaN
# 3      NaN   NaN    NaN    NaN   NaN   NaN  NaN
# 4      1.0   1.0  23201  193.0   NaN   NaN    E
# ...    ...   ...    ...    ...   ...   ...  ...
# 8288  60.0  67.0  63641  229.0   NaN   4.0    A
# 8289  60.0  67.0  63642  229.0   NaN   4.0    A
# 8290  60.0  67.0  63643  229.0   NaN   4.0    A
# 8291  60.0  67.0  63644  229.0   NaN   4.0    A
# 8292  60.0  67.0  63645  229.0   NaN   4.0    A
#
#                                         Zweckbestimmung      Ist 2012  \
# 0                Bundespräsident und Bundespräsidialamt           NaN
# 1                                       Bundespräsident           NaN
# 2                                             Einnahmen           NaN
# 3                                      Übrige Einnahmen           NaN
# 4     Beteiligung der Länder an der Deutschen Künstl...  1.083796e+06
# ...                                                 ...           ...
# 8288  Erstattung von Verwaltungskosten an die Deutsc...  1.285253e+07
# 8289  Erstattung an Sozialversicherungsträger für Re...  5.746716e+08
# 8290  Erstattung an Sozialversicherungsträger für Re...  7.871757e+08
# 8291  Erstattung an Sozialversicherungsträger für Re...  4.940458e+07
# 8292  Erstattung an Sozialversicherungsträger für Re...  2.652887e+08
#
#                  Umsatzgruppe (Hauptgruppe/Titelgruppe)   Seite
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                      Übrige Einnahmen    67.0
# ...                                                 ...     ...
# 8288  Leistungen nach dem Anspruchs- und Anwartschaf...  1454.0
# 8289  Leistungen nach dem Anspruchs- und Anwartschaf...  1454.0
# 8290  Leistungen nach dem Anspruchs- und Anwartschaf...  1455.0
# 8291  Leistungen nach dem Anspruchs- und Anwartschaf...  1455.0
# 8292  Leistungen nach dem Anspruchs- und Anwartschaf...  1455.0
#
# [8293 rows x 11 columns]

# %%
df_test.dtypes
# Out:
# Epl.                                      float64
# Kap.                                      float64
# Tit.                                       object
# Fkt.                                      float64
# Flex.                                      object
# Tgr.                                      float64
# E/A                                        object
# Zweckbestimmung                            object
# Ist 2012                                  float64
# Umsatzgruppe (Hauptgruppe/Titelgruppe)     object
# Seite                                     float64
# dtype: object

# %%
df_test = drop_nan(df_test)
df_test = make_id_col(df_test)

df_test_2 = drop_nan(df_test_2)
df_test_2 = make_id_col(df_test_2)

# %%
df_test
# Out:
#           Ist 2012                                    Zweckbestimmung  \
# 0     1.083796e+06  Beteiligung der Länder an der Deutschen Künstl...
# 1     1.988409e+05                       Bezüge des Bundespräsidenten
# 2     6.793548e+04                                       Aufwandsgeld
# 4     5.849732e+05  Außergewöhnlicher Aufwand aus dienstlicher Ver...
# 6     1.347210e+06  Übernahme von Patenschaften, Ausgaben aus beso...
# ...            ...                                                ...
# 6457  1.285253e+07  Erstattung von Verwaltungskosten an die Deutsc...
# 6458  5.746716e+08  Erstattung an Sozialversicherungsträger für Re...
# 6459  7.871757e+08  Erstattung an Sozialversicherungsträger für Re...
# 6460  4.940458e+07  Erstattung an Sozialversicherungsträger für Re...
# 6461  2.652887e+08  Erstattung an Sozialversicherungsträger für Re...
#
#              id
# 0     232010101
# 1     421010101
# 2     421020101
# 4     529010101
# 6     681010101
# ...         ...
# 6457  636416067
# 6458  636426067
# 6459  636436067
# 6460  636446067
# 6461  636456067
#
# [5401 rows x 3 columns]

# %%
df_test.shape , df_test_2.shape
# Out:
# ((5401, 3), (5241, 3))

# %%
pd.merge(df_test, df_test_2, on='id', how="inner")["Ist 2022"].sum() / df_test_2["Ist 2022"].sum(), pd.merge(df_test, df_test_2, on='id', how="inner")["Ist 2012"].sum() / df_test["Ist 2012"].sum()
# Out:
# (0.5869674806201383, 0.601035666135275)

# %%
pd.merge(df_test, df_test_2, on='id').shape[0], pd.merge(df_test, df_test_2, on='Zweckbestimmung').shape[0]
# Out:
# (1012, 238474)

# %%
pd.merge(df_test, df_test_2, on='Zweckbestimmung', how="left").shape[0], pd.merge(df_test, df_test_2, on='Zweckbestimmung', how="right").shape[0]
# Out:
# (239771, 240319)

# %%
merged_df = pd.merge(df_test, df_test_2, on='id', how="inner")
merged_df
# Out:
#           Ist 2012                                  Zweckbestimmung_x  \
# 0     1.083796e+06  Beteiligung der Länder an der Deutschen Künstl...
# 1     1.988409e+05                       Bezüge des Bundespräsidenten
# 2     6.793548e+04                                       Aufwandsgeld
# 3     5.849732e+05  Außergewöhnlicher Aufwand aus dienstlicher Ver...
# 4     1.347210e+06  Übernahme von Patenschaften, Ausgaben aus beso...
# ...            ...                                                ...
# 1007  1.285253e+07  Erstattung von Verwaltungskosten an die Deutsc...
# 1008  5.746716e+08  Erstattung an Sozialversicherungsträger für Re...
# 1009  7.871757e+08  Erstattung an Sozialversicherungsträger für Re...
# 1010  4.940458e+07  Erstattung an Sozialversicherungsträger für Re...
# 1011  2.652887e+08  Erstattung an Sozialversicherungsträger für Re...
#
#              id      Ist 2022  \
# 0     232010101  1.126700e+06
# 1     421010101  2.583531e+05
# 2     421020101  7.800000e+04
# 3     529010101  8.905984e+05
# 4     681010101  1.231512e+06
# ...         ...           ...
# 1007  636416067  2.562377e+06
# 1008  636426067  8.761600e+08
# 1009  636436067  8.587050e+08
# 1010  636446067  7.361706e+07
# 1011  636456067  4.492804e+08
#
#                                       Zweckbestimmung_y
# 0     Beteiligung der Länder an der Deutschen Künstl...
# 1                          Bezüge des Bundespräsidenten
# 2                                          Aufwandsgeld
# 3     Außergewöhnlicher Aufwand aus dienstlicher Ver...
# 4     Übernahme von Patenschaften, Ausgaben aus beso...
# ...                                                 ...
# 1007  Erstattung von Verwaltungskosten an die Deutsc...
# 1008  Erstattung an Sozialversicherungsträger für Re...
# 1009  Erstattung an Sozialversicherungsträger für Re...
# 1010  Erstattung an Sozialversicherungsträger für Re...
# 1011  Erstattung an Sozialversicherungsträger für Re...
#
# [1012 rows x 5 columns]

# %%
merged_df.sort_values("Ist 2012", ascending=False).iloc[:5]
# Out:
#          Ist 2012                                  Zweckbestimmung_x  \
# 909  7.608407e+10                                       Umsatzsteuer
# 905  6.313621e+10                                         Lohnsteuer
# 914  3.522622e+10  Energiesteuer (sonstiges Aufkommen, ohne das i...
# 910  2.788054e+10                                Einfuhrumsatzsteuer
# 897  2.323186e+10                          Zinsen für Bundesanleihen
#
#             id      Ist 2022  \
# 909  015016001  9.241173e+10
# 905  011016001  9.656430e+10
# 914  031036001  2.938877e+10
# 910  016016001  4.040062e+10
# 897  575013205  1.248070e+10
#
#                                      Zweckbestimmung_y
# 909                                       Umsatzsteuer
# 905                                         Lohnsteuer
# 914  Energiesteuer (sonstiges Aufkommen, ohne das i...
# 910                                Einfuhrumsatzsteuer
# 897                          Zinsen für Bundesanleihen

# %%
merged_df.sort_values("Ist 2022", ascending=False).head(5).reset_index()
# Out:
#    index      Ist 2012                       Zweckbestimmung_x         id  \
# 0    892  2.248003e+10  Einnahmen aus Krediten vom Kreditmarkt  325113201
# 1    905  6.313621e+10                              Lohnsteuer  011016001
# 2    909  7.608407e+10                            Umsatzsteuer  015016001
# 3    910  2.788054e+10                     Einfuhrumsatzsteuer  016016001
# 4    906  1.583799e+10              Veranlagte Einkommensteuer  012016001
#
#        Ist 2022                       Zweckbestimmung_y
# 0  1.154416e+11  Einnahmen aus Krediten vom Kreditmarkt
# 1  9.656430e+10                              Lohnsteuer
# 2  9.241173e+10                            Umsatzsteuer
# 3  4.040062e+10                     Einfuhrumsatzsteuer
# 4  3.289996e+10              Veranlagte Einkommensteuer

# %%
merged_df.sort_values("Ist 2022", ascending=False).head(30)["Ist 2022"].sum() / df_test_2["Ist 2022"].sum()
# Out:
# 0.5450717556784107

# %% [markdown]
# # Try to mapp more rows with col "Zweckbestimmung"

# %%
def make_id_col(df):
    df["id"] = df["Tit."].astype(str).str.zfill(5) + df["Epl."].astype(str).str.zfill(2) + df["Kap."].astype(str).str.zfill(2)
    #df = df.drop(["Epl.", "Kap.", "Tit."], axis=1)
    return df

# %% [markdown]
# def make_id_col(df, zahlen_dict):
#     df["id_help"] = df["Tit."].astype(str).str.zfill(5) + df["Epl."].astype(str).str.zfill(2) + df["Kap."].astype(str).str.zfill(2)
#     df["id"] = df["id_help"].apply(map_numbers) + df["Zweckbestimmung"]
#     #df["id"] = df["Zweckbestimmung"].astype(str) +" "+ df["Tit."].astype(str).str.zfill(5) + df["Epl."].astype(str).str.zfill(2) + df["Kap."].astype(str).str.zfill(2)
#     #df = df.drop(["Epl.", "Kap.", "Tit."], axis=1)
#     return df

# %% [markdown]
# def map_numbers(string):
#     string = " ".join([zahlen_dict[int(dig)] for dig in str(string)]) + " "
#     return string
#
# zahlen = "null, eins, zwei, drei, vier, fünf, sechs, sieben, acht, neun".split(", ")
# zahlen_dict = { k:v for k,v in zip(range(10), zahlen)}
# zahlen_dict

# %%
df_test = pd.read_excel("data/HR2012.xlsx")
df_test_2 = pd.read_excel("data/HR2022.xlsx")

# %%
# For some reason, drop_nan only reset index if its called two times
df_test = drop_nan(df_test)
df_test = drop_nan(df_test)
df_test = make_id_col(df_test)

df_test_2 = drop_nan(df_test_2)
df_test_2 = drop_nan(df_test_2)
df_test_2 = make_id_col(df_test_2)

# %%
df_test_2
# Out:
#       Epl.  Kap.   Tit.      Ist 2022  \
# 0        1     1  23201  1.126700e+06
# 1        1     1  52901  8.905984e+05
# 2        1     1  68101  1.231512e+06
# 3        1     1  68401  3.421900e+06
# 4        1     1  42101  2.583531e+05
# ...    ...   ...    ...           ...
# 5236    60    67  63641  2.562377e+06
# 5237    60    67  63642  8.761600e+08
# 5238    60    67  63643  8.587050e+08
# 5239    60    67  63644  7.361706e+07
# 5240    60    67  63645  4.492804e+08
#
#                                         Zweckbestimmung         id
# 0     Beteiligung der Länder an der Deutschen Künstl...  232010101
# 1     Außergewöhnlicher Aufwand aus dienstlicher Ver...  529010101
# 2     Übernahme von Patenschaften, Ausgaben aus beso...  681010101
# 3                                Deutsche Künstlerhilfe  684010101
# 4                          Bezüge des Bundespräsidenten  421010101
# ...                                                 ...        ...
# 5236  Erstattung von Verwaltungskosten an die Deutsc...  636416067
# 5237  Erstattung an Sozialversicherungsträger für Re...  636426067
# 5238  Erstattung an Sozialversicherungsträger für Re...  636436067
# 5239  Erstattung an Sozialversicherungsträger für Re...  636446067
# 5240  Erstattung an Sozialversicherungsträger für Re...  636456067
#
# [5241 rows x 6 columns]

# %%
"111268112 Arbeitslosengeld II"
# Out:
# '111268112 Arbeitslosengeld II'

# %%
idx_arbeit = df_test[df_test["Zweckbestimmung"] == "Arbeitslosengeld II"].index
df_test.iloc[idx_arbeit[0]]
# Out:
# Epl.                                11
# Kap.                                12
# Tit.                             68112
# Ist 2012                18951335517.59
# Zweckbestimmung    Arbeitslosengeld II
# id                           681121112
# Name: 3058, dtype: object

# %%
df_test_2[df_test_2["Zweckbestimmung"] == "Arbeitslosengeld II"]["id"].iloc[0]
# Out:
# '681121101'

# %%
df_test[df_test["id"].str.startswith("68112")]#.iloc[0,-1]
# Out:
#       Epl.  Kap.   Tit.      Ist 2012  \
# 594      5     2  68112  3.248134e+05
# 1418     6    40  68112  3.761538e+06
# 3058    11    12  68112  1.895134e+10
# 5166    30     2  68112  1.751945e+07
#
#                                         Zweckbestimmung         id
# 594   Einmalige Bewilligungen für ehemalige Bedienst...  681120502
# 1418  Eingliederungshilfen und Unterstützungsleistungen  681120640
# 3058                                Arbeitslosengeld II  681121112
# 5166                      Nationales Stipendienprogramm  681123002

# %%
df_test_2[df_test_2["Tit."] == 68112]
# Out:
#       Epl.  Kap.   Tit.      Ist 2022  \
# 691      5     1  68112  6.443541e+04
# 3226    11     1  68112  2.227577e+10
# 6234    30     2  68112  3.682207e+07
#
#                                         Zweckbestimmung         id
# 691   Einmalige Bewilligungen für ehemalige Bedienst...  681120501
# 3226                                Arbeitslosengeld II  681121101
# 6234                              Deutschlandstipendium  681123002

# %%
df_test[df_test["Tit."] == 68112]
# Out:
#       Epl.  Kap.   Tit.      Ist 2012  \
# 737      5     2  68112  3.248134e+05
# 1702     6    40  68112  3.761538e+06
# 3676    11    12  68112  1.895134e+10
# 6175    30     2  68112  1.751945e+07
#
#                                         Zweckbestimmung         id
# 737   Einmalige Bewilligungen für ehemalige Bedienst...  681120502
# 1702  Eingliederungshilfen und Unterstützungsleistungen  681120640
# 3676                                Arbeitslosengeld II  681121112
# 6175                      Nationales Stipendienprogramm  681123002

# %%
df_test_2["id"].tolist()[661]
# Out:
# '812120512'

# %%
111268112 Arbeitslosengeld II, 2.227577e+10
# Out:
#   Cell In[80], line 1
#     111268112 Arbeitslosengeld II, 2.227577e+10
#               ^
# SyntaxError: invalid syntax

# %%
2.227577e+10
# Out:
# 22275770000.0

# %%
df_test_2[df_test_2["Tit."] == 68112]
# Out:
#       Epl.  Kap.   Tit.      Ist 2022  \
# 691      5     1  68112  6.443541e+04
# 3226    11     1  68112  2.227577e+10
# 6234    30     2  68112  3.682207e+07
#
#                                         Zweckbestimmung         id
# 691   Einmalige Bewilligungen für ehemalige Bedienst...  681120501
# 3226                                Arbeitslosengeld II  681121101
# 6234                              Deutschlandstipendium  681123002

# %%
111268112 Arbeitslosengeld II,
# Out:
#   Cell In[83], line 1
#     111268112 Arbeitslosengeld II,
#               ^
# SyntaxError: invalid syntax

# %%
merged_df = pd.merge(df_test, df_test_2, on='Zweckbestimmung', how="left")
merged_df[merged_df["Tit._x"] == 68112]
# Out:
#         Epl._x  Kap._x  Tit._x      Ist 2012  \
# 26127        5       2   68112  3.248134e+05
# 67540        6      40   68112  3.761538e+06
# 148084      11      12   68112  1.895134e+10
# 238016      30       2   68112  1.751945e+07
#
#                                           Zweckbestimmung       id_x  Epl._y  \
# 26127   Einmalige Bewilligungen für ehemalige Bedienst...  681120502     5.0
# 67540   Eingliederungshilfen und Unterstützungsleistungen  681120640     6.0
# 148084                                Arbeitslosengeld II  681121112    11.0
# 238016                      Nationales Stipendienprogramm  681123002     NaN
#
#         Kap._y   Tit._y      Ist 2022       id_y
# 26127      1.0  68112.0  6.443541e+04  681120501
# 67540      3.0  68122.0  1.265323e+06  681220603
# 148084     1.0  68112.0  2.227577e+10  681121101
# 238016     NaN      NaN           NaN        NaN

# %%
merged_df = pd.merge(df_test, df_test_2, on='Zweckbestimmung', how="right")
merged_df[merged_df["Tit._y"] == 68112]
# Out:
#         Epl._x  Kap._x   Tit._x      Ist 2012  \
# 24727      5.0     2.0  68112.0  3.248134e+05
# 128108    11.0    12.0  68112.0  1.895134e+10
# 236035     NaN     NaN      NaN           NaN
#
#                                           Zweckbestimmung       id_x  Epl._y  \
# 24727   Einmalige Bewilligungen für ehemalige Bedienst...  681120502       5
# 128108                                Arbeitslosengeld II  681121112      11
# 236035                              Deutschlandstipendium        NaN      30
#
#         Kap._y  Tit._y      Ist 2022       id_y
# 24727        1   68112  6.443541e+04  681120501
# 128108       1   68112  2.227577e+10  681121101
# 236035       2   68112  3.682207e+07  681123002

# %%
merged_df = pd.merge(df_test_2, df_test, on='Zweckbestimmung', how="outer")
merged_df[merged_df["Tit._x"] == 68112]
# Out:
#         Epl._x  Kap._x   Tit._x      Ist 2022  \
# 235714     5.0     1.0  68112.0  6.443541e+04
# 238927    11.0     1.0  68112.0  2.227577e+10
# 240063    30.0     2.0  68112.0  3.682207e+07
#
#                                           Zweckbestimmung       id_x  Epl._y  \
# 235714  Einmalige Bewilligungen für ehemalige Bedienst...  681120501     5.0
# 238927                                Arbeitslosengeld II  681121101    11.0
# 240063                              Deutschlandstipendium  681123002     NaN
#
#         Kap._y   Tit._y      Ist 2012       id_y
# 235714     2.0  68112.0  3.248134e+05  681120502
# 238927    12.0  68112.0  1.895134e+10  681121112
# 240063     NaN      NaN           NaN        NaN

# %%
df_test_2[df_test_2["Tit."] == 68112]
# Out:
#       Epl.  Kap.   Tit.      Ist 2022  \
# 691      5     1  68112  6.443541e+04
# 3226    11     1  68112  2.227577e+10
# 6234    30     2  68112  3.682207e+07
#
#                                         Zweckbestimmung         id
# 691   Einmalige Bewilligungen für ehemalige Bedienst...  681120501
# 3226                                Arbeitslosengeld II  681121101
# 6234                              Deutschlandstipendium  681123002

# %%
df_test[df_test["Tit."] == 68112]
# Out:
#       Epl.  Kap.   Tit.      Ist 2012  \
# 737      5     2  68112  3.248134e+05
# 1702     6    40  68112  3.761538e+06
# 3676    11    12  68112  1.895134e+10
# 6175    30     2  68112  1.751945e+07
#
#                                         Zweckbestimmung         id
# 737   Einmalige Bewilligungen für ehemalige Bedienst...  681120502
# 1702  Eingliederungshilfen und Unterstützungsleistungen  681120640
# 3676                                Arbeitslosengeld II  681121112
# 6175                      Nationales Stipendienprogramm  681123002

# %%
df_test_2["id"].tolist()
# Out:
# ['232010101',
#  '529010101',
#  '681010101',
#  '684010101',
#  '421010101',
#  '421020101',
#  '232570111',
#  '542010111',
#  '981030111',
#  '431570111',
#  '432570111',
#  '434570111',
#  '446570111',
#  '424010111',
#  '441010111',
#  '443010111',
#  '452020111',
#  '526010111',
#  '526020111',
#  '545010111',
#  '634030111',
#  '119990112',
#  '132010112',
#  '685010112',
#  '981030112',
#  '422010112',
#  '427090112',
#  '428010112',
#  '453010112',
#  '511010112',
#  '514010112',
#  '517010112',
#  '518010112',
#  '519010112',
#  '525010112',
#  '527010112',
#  '532010112',
#  '532040112',
#  '532050112',
#  '539990112',
#  '711010112',
#  '812010112',
#  '812020112',
#  '132010113',
#  '282090113',
#  '518020113',
#  '529010113',
#  '422010113',
#  '427090113',
#  '428010113',
#  '441010113',
#  '443010113',
#  '511010113',
#  '518010113',
#  '532010113',
#  '539990113',
#  '634030113',
#  '812020113',
#  '232570211',
#  '529010211',
#  '542010211',
#  '981030211',
#  '431570211',
#  '432570211',
#  '434570211',
#  '443570211',
#  '446570211',
#  '632570211',
#  '424010211',
#  '441010211',
#  '443010211',
#  '443020211',
#  '452020211',
#  '526010211',
#  '526020211',
#  '527030211',
#  '634030211',
#  '111010212',
#  '119010212',
#  '119990212',
#  '124010212',
#  '132010212',
#  '381030212',
#  '411010212',
#  '411020212',
#  '411030212',
#  '411040212',
#  '411050212',
#  '411110212',
#  '411120212',
#  '411160212',
#  '411170212',
#  '411180212',
#  '411190212',
#  '411200212',
#  '684010212',
#  '685010212',
#  '685020212',
#  '685120212',
#  '687010212',
#  '687020212',
#  '981030212',
#  '422010212',
#  '422020212',
#  '422030212',
#  '427090212',
#  '428010212',
#  '453010212',
#  '459090212',
#  '511010212',
#  '514010212',
#  '517010212',
#  '518010212',
#  '519010212',
#  '525010212',
#  '526030212',
#  '527010212',
#  '531020212',
#  '531050212',
#  '531060212',
#  '532010212',
#  '532040212',
#  '532050212',
#  '532060212',
#  '539990212',
#  '711010212',
#  '712010212',
#  '811010212',
#  '812010212',
#  '812020212',
#  '812030212',
#  '812040212',
#  '812060212',
#  '428910212',
#  '517910212',
#  '519910212',
#  '547910212',
#  '427590212',
#  '511560212',
#  '525560212',
#  '532510212',
#  '711560212',
#  '712560212',
#  '812520212',
#  '421010213',
#  '422010213',
#  '422020213',
#  '428010213',
#  '517010213',
#  '519010213',
#  '527010213',
#  '539990213',
#  '545010213',
#  '811010213',
#  '812010213',
#  '411010214',
#  '539990214',
#  '542010214',
#  '411010215',
#  '411040215',
#  '411110215',
#  '411120215',
#  '411200215',
#  '422010216',
#  '422020216',
#  '428010216',
#  '517010216',
#  '526050216',
#  '527010216',
#  '539990216',
#  '421010217',
#  '422010217',
#  '428010217',
#  '453010217',
#  '517010217',
#  '527010217',
#  '539990217',
#  '545010217',
#  '812010217',
#  '232570311',
#  '529010311',
#  '542010311',
#  '432570311',
#  '434570311',
#  '446570311',
#  '424010311',
#  '441010311',
#  '443010311',
#  '452020311',
#  '526010311',
#  '634030311',
#  '119990312',
#  '124010312',
#  '411010312',
#  '411020312',
#  '518020312',
#  '532040312',
#  '687010312',
#  '981030312',
#  '422010312',
#  '422020312',
#  '427090312',
#  '428010312',
#  '511010312',
#  '517010312',
#  '518010312',
#  '519010312',
#  '527010312',
#  '531060312',
#  '532010312',
#  '532050312',
#  '539990312',
#  '812010312',
#  '812020312',
#  '812030312',
#  '532040410',
#  '532060410',
#  '685010410',
#  '981030410',
#  '547010410',
#  '685020410',
#  '232570411',
#  '529010411',
#  '981010411',
#  '981070411',
#  '431570411',
#  '432570411',
#  '434570411',
#  '443570411',
#  '446570411',
#  '632570411',
#  '424010411',
#  '441010411',
#  '443010411',
#  '452020411',
#  '526010411',
#  '526020411',
#  '527030411',
#  '545010411',
#  '111010412',
#  '119990412',
#  '381030412',
#  '529040412',
#  '532050412',
#  '981030412',
#  '421010412',
#  '422010412',
#  '422020412',
#  '427090412',
#  '428010412',
#  '453010412',
#  '511010412',
#  '514010412',
#  '517010412',
#  '518010412',
#  '519010412',
#  '525010412',
#  '527010412',
#  '532010412',
#  '539990412',
#  '634030412',
#  '711010412',
#  '712010412',
#  '811010412',
#  '812010412',
#  '812020412',
#  '119990413',
#  '542010413',
#  '684010413',
#  '684020413',
#  '684030413',
#  '981030413',
#  '422010413',
#  '422020413',
#  '427090413',
#  '428010413',
#  '453010413',
#  '511010413',
#  '526020413',
#  '527010413',
#  '531010413',
#  '539990413',
#  '545010413',
#  '634030413',
#  '541010414',
#  '531010415',
#  '542010415',
#  '686010415',
#  '422010415',
#  '428010415',
#  '539990415',
#  '529010431',
#  '542010431',
#  '981010431',
#  '431570431',
#  '432570431',
#  '434570431',
#  '443570431',
#  '446570431',
#  '632570431',
#  '424010431',
#  '441010431',
#  '443010431',
#  '452020431',
#  '526010431',
#  '526020431',
#  '527030431',
#  '634030431',
#  '119010432',
#  '119990432',
#  '124010432',
#  '381030432',
#  '518020432',
#  '531090432',
#  '532050432',
#  '542030432',
#  '544010432',
#  '546010432',
#  '685050432',
#  '685060432',
#  '981030432',
#  '422010432',
#  '427090432',
#  '428010432',
#  '511010432',
#  '514010432',
#  '517010432',
#  '518010432',
#  '519010432',
#  '525010432',
#  '527010432',
#  '532010432',
#  '539990432',
#  '711010432',
#  '812010432',
#  '812020432',
#  '232570451',
#  '529010451',
#  '542010451',
#  '431570451',
#  '432570451',
#  '434570451',
#  '446570451',
#  '632570451',
#  '424010451',
#  '441010451',
#  '443010451',
#  '452020451',
#  '526010451',
#  '526020451',
#  '527030451',
#  '543010451',
#  '545010451',
#  '634030451',
#  '119990452',
#  '132010452',
#  '232010452',
#  '272010452',
#  '518020452',
#  '687010452',
#  '981030452',
#  '532140452',
#  '544110452',
#  '632110452',
#  '681110452',
#  '684120452',
#  '684140452',
#  '684150452',
#  '684170452',
#  '685100452',
#  '685120452',
#  '685140452',
#  '685150452',
#  '685160452',
#  '685170452',
#  '685180452',
#  '685190452',
#  '686120452',
#  '686130452',
#  '894110452',
#  '894120452',
#  '894160452',
#  '894170452',
#  '683210452',
#  '683220452',
#  '683230452',
#  '683240452',
#  '683250452',
#  '684210452',
#  '684220452',
#  '685210452',
#  '685220452',
#  '685240452',
#  '685250452',
#  '685260452',
#  '892220452',
#  '894210452',
#  '894220452',
#  '894230452',
#  '894240452',
#  '532330452',
#  '685310452',
#  '894310452',
#  '894320452',
#  '894340452',
#  '685410452',
#  '894410452',
#  '687510452',
#  '812530452',
#  '894510452',
#  '684610452',
#  '685610452',
#  '685630452',
#  '894610452',
#  '894650452',
#  '632710452',
#  '684710452',
#  '684720452',
#  '686710452',
#  '687720452',
#  '893720452',
#  '685910452',
#  '685920452',
#  '894910452',
#  '421010452',
#  '422010452',
#  '422020452',
#  '427090452',
#  '428010452',
#  '453010452',
#  '511010452',
#  '514010452',
#  '517010452',
#  '518010452',
#  '519010452',
#  '525010452',
#  '527010452',
#  '531030452',
#  '532010452',
#  '539990452',
#  '812010452',
#  '812020452',
#  '894100452',
#  '111010453',
#  '119010453',
#  '119990453',
#  '124010453',
#  '132010453',
#  '282010453',
#  '381030453',
#  '518020453',
#  '632010453',
#  '686010453',
#  '687010453',
#  '981030453',
#  '422010453',
#  '422020453',
#  '422030453',
#  '427090453',
#  '428010453',
#  '453010453',
#  '511010453',
#  '514010453',
#  '517010453',
#  '518010453',
#  '519010453',
#  '523010453',
#  '525010453',
#  '527010453',
#  '532010453',
#  '532040453',
#  '532070453',
#  '532080453',
#  '539990453',
#  '711010453',
#  '712010453',
#  '811010453',
#  '812010453',
#  '812020453',
#  '119990454',
#  '518020454',
#  '981030454',
#  '422010454',
#  '427090454',
#  '428010454',
#  '511010454',
#  '517010454',
#  '518010454',
#  '525010454',
#  '527010454',
#  '532010454',
#  '539990454',
#  '544010454',
#  '812020454',
#  '381030456',
#  '518020456',
#  '981030456',
#  '422010456',
#  '427090456',
#  '428010456',
#  '511010456',
#  '514010456',
#  '517010456',
#  '518010456',
#  '525010456',
#  '527010456',
#  '532010456',
#  '539990456',
#  '812020456',
#  '119990501',
#  '381030501',
#  '981030501',
#  '517110501',
#  '518120501',
#  '525110501',
#  '681110501',
#  '681120501',
#  '687100501',
#  '687120501',
#  '687140501',
#  '687170501',
#  '812110501',
#  '687210501',
#  '687230501',
#  '687270501',
#  '685300501',
#  '686300501',
#  '687320501',
#  '687340501',
#  '687380501',
#  '525410501',
#  '532450501',
#  '544410501',
#  '687400501',
#  '687430501',
#  '119990502',
#  '381030502',
#  '539990502',
#  '685010502',
#  '981030502',
#  '518120502',
#  '531140502',
#  '532140502',
#  '685170502',
#  '687100502',
#  '687120502',
#  '687130502',
#  '687160502',
#  '687910502',
#  '896120502',
#  '526240502',
#  '529220502',
#  '532290502',
#  '539290502',
#  '546260502',
#  '632210502',
#  '685200502',
#  '685210502',
#  '685250502',
#  '687270502',
#  '119990504',
#  '131010504',
#  '381030504',
#  '981030504',
#  '546110504',
#  '681110504',
#  '687100504',
#  '687110504',
#  '687120504',
#  '687130504',
#  '687140504',
#  '687150504',
#  '687160504',
#  '687170504',
#  '687180504',
#  '687910504',
#  '687920504',
#  '687930504',
#  '427290504',
#  '429210504',
#  '632210504',
#  '687200504',
#  '687210504',
#  '687220504',
#  '687260504',
#  '687270504',
#  '518420504',
#  '681410504',
#  '687400504',
#  '687460504',
#  '687470504',
#  '687480504',
#  '893400504',
#  '893470504',
#  '519310504',
#  '539390504',
#  '711310504',
#  '739310504',
#  '896310504',
#  '282090511',
#  '381030511',
#  '381070511',
#  '119570511',
#  '232570511',
#  '529010511',
#  '542010511',
#  '547090511',
#  '981030511',
#  '431570511',
#  '432570511',
#  '434570511',
#  '443570511',
#  '446570511',
#  '632570511',
#  '424010511',
#  '441010511',
#  '443010511',
#  '452020511',
#  '526010511',
#  '526020511',
#  '526040511',
#  '527030511',
#  '532020511',
#  '543010511',
#  '545010511',
#  '634030511',
#  '684090511',
#  '381030512',
#  '381070512',
#  '111110512',
#  '119110512',
#  '119190512',
#  '124110512',
#  '132110512',
#  '111210512',
#  '119290512',
#  '124210512',
#  '131220512',
#  '132210512',
#  '518020512',
#  '529030512',
#  '981030512',
#  '412110512',
#  '421110512',
#  '422110512',
#  '422120512',
#  '427190512',
#  '428110512',
#  '453110512',
#  '459190512',
#  '511110512',
#  '514110512',
#  '517110512',
#  '518110512',
#  '519110512',
#  '525110512',
#  '527110512',
#  '532110512',
#  '539190512',
#  '711110512',
#  '812110512',
#  '812120512',
#  '422210512',
#  '422220512',
#  '422230512',
#  '427290512',
#  '428210512',
#  '511210512',
#  '514210512',
#  '517210512',
#  '518210512',
#  '519210512',
#  '527210512',
#  '532240512',
#  '539290512',
#  '687220512',
#  '711210512',
#  '739210512',
#  '811210512',
#  '812210512',
#  '821210512',
#  '422320512',
#  '427390512',
#  '428310512',
#  '514310512',
#  '517310512',
#  '518310512',
#  '519310512',
#  '525310512',
#  '532310512',
#  '711310512',
#  '739310512',
#  '811310512',
#  '812310512',
#  '812320512',
#  '422410512',
#  '428410512',
#  '111010513',
#  '119010513',
#  '119990513',
#  '272010513',
#  '381010513',
#  '428020513',
#  '518020513',
#  '681010513',
#  '685010513',
#  '981030513',
#  '427290513',
#  '428220513',
#  '518210513',
#  '547210513',
#  '427490513',
#  '429410513',
#  '547410513',
#  '422010513',
#  '427090513',
#  '428010513',
#  '453010513',
#  '511010513',
#  '514010513',
#  '517010513',
#  '518010513',
#  '519010513',
#  '525010513',
#  '527010513',
#  '532010513',
#  '539990513',
#  '739010513',
#  '811010513',
#  '812010513',
#  '812020513',
#  '427190513',
#  '544110513',
#  '547110513',
#  '518020514',
#  '981030514',
#  '422010514',
#  '427090514',
#  '428010514',
#  '453010514',
#  '511010514',
#  '514010514',
#  '517010514',
#  '518010514',
#  '525010514',
#  '527010514',
#  '532010514',
#  '539990514',
#  '812010514',
#  '812020514',
#  '119990601',
#  '272010601',
#  '681110601',
#  '981030601',
#  '532120601',
#  '532140601',
#  '632130601',
#  '684130601',
#  '685110601',
#  '685120601',
#  '685140601',
#  '685150601',
#  '685160601',
#  '685190601',
#  '687110601',
#  '894120601',
#  '428210601',
#  '681210601',
#  '684210601',
#  '684220601',
#  '684230601',
#  '684240601',
#  '684250601',
#  '684260601',
#  '684270601',
#  '684280601',
#  '686210601',
#  '686220601',
#  '686230601',
#  '686240601',
#  '686260601',
#  '686270601',
#  '882210601',
#  '882220601',
#  '532440601',
#  '532470601',
#  '532480601',
#  '532490601',
#  '632410601',
#  '632440601',
#  '632450601',
#  '685450601',
#  '119990602',
#  '232010602',
#  '381030602',
#  '532060602',
#  '532180602',
#  '981030602',
#  '532100602',
#  '532130602',
#  '532140602',
#  '532170602',
#  '685100602',
#  '686110602',
#  '511210602',
#  '517210602',
#  '518210602',
#  '519210602',
#  '525210602',
#  '539290602',
#  '685200602',
#  '711210602',
#  '812200602',
#  '894200602',
#  '532340602',
#  '532360602',
#  '532370602',
#  '532380602',
#  '632310602',
#  '632330602',
#  '686310602',
#  '687310602',
#  '812320602',
#  '422410602',
#  '428410602',
#  '532410602',
#  '812420602',
#  '532510602',
#  '685510602',
#  '894510602',
#  '532610602',
#  '812620602',
#  '119990603',
#  '182040603',
#  '272020603',
#  '381030603',
#  '532040603',
#  '681020603',
#  '681040603',
#  '681050603',
#  '684020603',
#  '684030603',
#  '684040603',
#  '685020603',
#  '685030603',
#  '685060603',
#  '685070603',
#  '981030603',
#  '684100603',
#  '684110603',
#  '684120603',
#  '684130603',
#  '684140603',
#  '684150603',
#  '684160603',
#  '684610603',
#  '685100603',
#  '685190603',
#  '686100603',
#  '671240603',
#  '671250603',
#  '681220603',
#  '684230603',
#  '684320603',
#  '896320603',
#  '632500603',
#  '687500603',
#  '896500603',
#  '119990610',
#  '132010610',
#  '532030610',
#  '532060610',
#  '686040610',
#  '687070610',
#  '981030610',
#  '539190610',
#  '811110610',
#  '812110610',
#  '282090611',
#  '381030611',
#  '381070611',
#  '232570611',
#  '529010611',
#  '542010611',
#  '547090611',
#  '687200611',
#  '981030611',
#  '981070611',
#  '431570611',
#  '432570611',
#  '434570611',
#  '443570611',
#  '446570611',
#  '632570611',
#  '424010611',
#  '441010611',
#  '443010611',
#  '452020611',
#  '526010611',
#  '526020611',
#  '527030611',
#  '531030611',
#  '543010611',
#  '545010611',
#  '634030611',
#  '111010612',
#  '119990612',
#  '132010612',
#  '381030612',
#  '518020612',
#  '546020612',
#  '981030612',
#  '412010612',
#  '421010612',
#  '422010612',
#  '422020612',
#  '427090612',
#  '428010612',
#  '453010612',
#  '511010612',
#  '514010612',
#  '517010612',
#  '518010612',
#  '519010612',
#  '525010612',
#  '527010612',
#  '532010612',
#  '532020612',
#  '539990612',
#  '544010612',
#  '711010612',
#  '811010612',
#  '812010612',
#  '812020612',
#  '422110612',
#  '427190612',
#  '428110612',
#  '525110612',
#  '527110612',
#  '112010614',
#  '119990614',
#  '132010614',
#  '381010614',
#  '381030614',
#  '518020614',
#  '981010614',
#  '427190614',
#  '428110614',
#  '547110614',
#  '422010614',
#  '427090614',
#  '428010614',
#  '453010614',
#  '511010614',
#  '517010614',
#  '518010614',
#  '519010614',
#  '525010614',
#  '527010614',
#  '532010614',
#  '532030614',
#  '539090614',
#  '684090614',
#  '711010614',
#  '712030614',
#  '811010614',
#  '812010614',
#  '812020614',
#  '422310614',
#  '427390614',
#  '428310614',
#  '526320614',
#  '812310614',
#  '111010615',
#  '119990615',
#  '124010615',
#  '125010615',
#  '132010615',
#  '381010615',
#  '381030615',
#  '518020615',
#  '981010615',
#  '981030615',
#  '422010615',
#  '422030615',
#  '427090615',
#  '428010615',
#  '453010615',
#  '511010615',
#  '514010615',
#  '517010615',
#  '518010615',
#  '519010615',
#  '525010615',
#  '527010615',
#  '532010615',
#  '532020615',
#  '539990615',
#  '681080615',
#  '711010615',
#  ...]

# %%
#embedding_model_name = "neuml/pubmedbert-base-embeddings"
#embeddings_short = txtai.Embeddings(path=embedding_model_name, content=False)
#embeddings_short.index(zip(codes["DIAGNOSIS CODE"], codes["SHORT DESCRIPTION"]))
#embeddings_short.save("/data/embeddings/embeddings_short")
#results_short = short_desc_index.batchsearch(flattened_predicted_diag_names, limit=1)

# %%
#embedding_model_name = "neuml/pubmedbert-base-embeddings"
embeddings_short = txtai.Embeddings()

# %%
embeddings_short.index(df_test_2["id"].tolist())
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
embeddings_short = txtai.Embeddings().load("/data/embeddings/embeddings_short")

# %%
embeddings_short.save("/data/embeddings/embeddings_short")

# %%
embeddings_short = txtai.Embeddings(path=embedding_model_name, content=False)

# %% [markdown]
# # Make pipeline

# %%
def make_id_col(df):
    df["id"] = df["Tit."].astype(str).str.zfill(5) + df["Epl."].astype(str).str.zfill(2) + df["Kap."].astype(str).str.zfill(2)
    df = df.drop(["Epl.", "Kap.", "Tit."], axis=1)
    return df

# %%
# %%time
df_res = pipeline((12,24))
# Out:
# C:\Users\sebas\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# CPU times: total: 51.3 s
# Wall time: 51.5 s

# %%
df_res = df_res.sort_values("Ist 2023", ascending=False)
df_res
# Out:
#             id                                    Zweckbestimmung  \
# 808  015016001                                       Umsatzsteuer
# 804  011016001                                         Lohnsteuer
# 809  016016001                                Einfuhrumsatzsteuer
# 813  031036001  Energiesteuer (sonstiges Aufkommen, ohne das i...
# 805  012016001                         Veranlagte Einkommensteuer
# ..         ...                                                ...
# 609  124011214  Einnahmen aus Vermietung, Verpachtung und Nutzung
# 369  711010915            Kleine Neu-, Um- und Erweiterungsbauten
# 853  281016003  Einnahmen aus Rückforderungen wegen unrechtmäß...
# 411  547410916    Nicht aufteilbare sächliche Verwaltungsausgaben
# 330  124010914  Einnahmen aus Vermietung, Verpachtung und Nutzung
#
#          Ist 2012      Ist 2013      Ist 2014      Ist 2015      Ist 2016  \
# 808  7.608407e+10  7.917711e+10  8.246040e+10  8.309309e+10  8.203658e+10
# 804  6.313621e+10  6.717432e+10  7.141968e+10  7.602806e+10  7.851858e+10
# 809  2.788054e+10  2.590640e+10  2.613589e+10  2.660053e+10  2.529200e+10
# 813  3.522622e+10  3.511706e+10  3.552215e+10  3.600326e+10  3.645493e+10
# 805  1.583799e+10  1.796892e+10  1.938512e+10  2.064707e+10  2.287918e+10
# ..            ...           ...           ...           ...           ...
# 609  2.286965e+05  1.702515e+05  1.643971e+05  1.297399e+05  8.020474e+04
# 369  1.615646e+06  1.513405e+06  1.365480e+06  2.616001e+06  3.474465e+06
# 853  2.735203e+04  2.284789e+05  7.993039e+04  3.159710e+04  2.719166e+04
# 411  7.881745e+05  5.623443e+05  2.892366e+05  7.800886e+04  4.933282e+04
# 330  1.384428e+04  5.883690e+03  7.263960e+03  7.263960e+03  2.103960e+03
#
#          Ist 2017      Ist 2018      Ist 2019      Ist 2020      Ist 2021  \
# 808  8.647531e+10  8.705545e+10  8.953635e+10  7.255127e+10  8.463254e+10
# 804  8.312150e+10  8.851997e+10  9.331063e+10  8.907473e+10  9.267056e+10
# 809  2.832992e+10  2.945726e+10  2.940793e+10  2.184020e+10  2.849295e+10
# 813  3.659441e+10  3.675357e+10  3.671889e+10  3.351130e+10  3.310098e+10
# 805  2.525631e+10  2.567763e+10  2.707763e+10  2.506692e+10  3.074644e+10
# ..            ...           ...           ...           ...           ...
# 609  1.282176e+04  1.258176e+04  1.258176e+04  1.258176e+04  1.258176e+04
# 369  1.876919e+06  8.582613e+05  6.383259e+05  8.080972e+05  6.709189e+04
# 853  2.587008e+04  2.572460e+03  2.652272e+05  9.208910e+03  1.272041e+04
# 411  2.389342e+04  7.392067e+04  7.495090e+04  2.119562e+04  1.856748e+04
# 330  1.242396e+04  7.263960e+03  7.263960e+03  7.263960e+03  6.672000e+03
#
#          Ist 2022      Ist 2023
# 808  9.241173e+10  1.010134e+11
# 804  9.656430e+10  1.003821e+11
# 809  4.040062e+10  3.743929e+10
# 813  2.938877e+10  3.307486e+10
# 805  3.289996e+10  3.119034e+10
# ..            ...           ...
# 609  1.258176e+04  4.807330e+03
# 369  4.968671e+05  4.247010e+03
# 853  1.675420e+03  2.999370e+03
# 411  2.124640e+03  2.618500e+03
# 330  1.512000e+03  2.484000e+03
#
# [903 rows x 14 columns]

# %%
df_res.to_csv("data/HR10y_on_id.csv")

# %%
df_res.iloc[3:13]
# Out:
#             id                                    Zweckbestimmung  \
# 813  031036001  Energiesteuer (sonstiges Aufkommen, ohne das i...
# 805  012016001                         Veranlagte Einkommensteuer
# 807  014016001                                 Körperschaftsteuer
# 806  013016001  Nicht veranlagte Steuern vom Ertrag (ohne das ...
# 820  036026001                                 Versicherungsteuer
# 815  032026001                                        Tabaksteuer
# 797  575013205                          Zinsen für Bundesanleihen
# 822  038016001                                         Kfz-Steuer
# 845  685016002        Zuschuss an die Postbeamtenversorgungskasse
# 647  423011403  Bezüge und Nebenleistungen der Berufssoldatinn...
#
#          Ist 2012      Ist 2013      Ist 2014      Ist 2015      Ist 2016  \
# 813  3.522622e+10  3.511706e+10  3.552215e+10  3.600326e+10  3.645493e+10
# 805  1.583799e+10  1.796892e+10  1.938512e+10  2.064707e+10  2.287918e+10
# 807  8.467229e+09  9.753803e+09  1.002201e+10  9.791505e+09  1.372097e+10
# 806  1.002753e+10  8.630587e+09  8.712184e+09  8.967812e+09  9.730919e+09
# 820  1.113797e+10  1.155277e+10  1.204621e+10  1.241947e+10  1.276322e+10
# 815  1.414345e+10  1.381994e+10  1.461174e+10  1.492092e+10  1.418606e+10
# 797  2.323186e+10  2.428831e+10  2.262651e+10  2.148366e+10  2.080560e+10
# 822  8.442660e+09  8.490321e+09  8.501012e+09  8.804826e+09  8.952083e+09
# 845  6.716500e+09  6.930500e+09  7.207700e+09  7.400500e+09  7.461900e+09
# 647  6.084406e+09  6.147241e+09  6.201289e+09  6.297758e+09  6.366812e+09
#
#          Ist 2017      Ist 2018      Ist 2019      Ist 2020      Ist 2021  \
# 813  3.659441e+10  3.675357e+10  3.671889e+10  3.351130e+10  3.310098e+10
# 805  2.525631e+10  2.567763e+10  2.707763e+10  2.506692e+10  3.074644e+10
# 807  1.462944e+10  1.671272e+10  1.600665e+10  1.213384e+10  2.106197e+10
# 806  1.045070e+10  1.159203e+10  1.172445e+10  1.076111e+10  1.369546e+10
# 820  1.326932e+10  1.377878e+10  1.413591e+10  1.455341e+10  1.497988e+10
# 815  1.439883e+10  1.433901e+10  1.425683e+10  1.465092e+10  1.473252e+10
# 797  1.868023e+10  1.756761e+10  1.589691e+10  1.622253e+10  1.379658e+10
# 822  8.947729e+09  9.046955e+09  9.372266e+09  9.526381e+09  9.546430e+09
# 845  7.885000e+09  8.129500e+09  8.384000e+09  8.468100e+09  8.696400e+09
# 647  6.646991e+09  6.943968e+09  7.317353e+09  7.641803e+09  7.757397e+09
#
#          Ist 2022      Ist 2023
# 813  2.938877e+10  3.307486e+10
# 805  3.289996e+10  3.119034e+10
# 807  2.316691e+10  2.242582e+10
# 806  1.631321e+10  1.822084e+10
# 820  1.567192e+10  1.685067e+10
# 815  1.422942e+10  1.467181e+10
# 797  1.248070e+10  1.302724e+10
# 822  9.498884e+09  9.514262e+09
# 845  8.865300e+09  9.318500e+09
# 647  7.893807e+09  8.296840e+09

# %%
df_plot = df_res.iloc[20:25,1:].set_index("Zweckbestimmung").T.copy()

# %%
df_plot = df_res.iloc[:6,1:].set_index("Zweckbestimmung").T.copy()
plt.figure(figsize=(12, 8))
plt.style.use('ggplot')
plt.legend(fontsize=12, loc="best")
df_plot.plot(ax=plt.gca())
#plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <Axes: >

# %%
df_plot = df_res.iloc[6:11,1:].set_index("Zweckbestimmung").T.copy()
# Setting a larger figure size and applying a style
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
plt.style.use('seaborn-darkgrid')  # You can choose other styles like 'ggplot', 'fivethirtyeight', etc.

# Plotting the DataFrame
df_plot.plot(ax=plt.gca())  # Use the current Axes to apply size and style
plt.title("My Fancy Plot", fontsize=16, fontweight='bold')  # Adding a title
plt.xlabel("X-axis Label", fontsize=14)  # Customizing the x-axis label
plt.ylabel("Y-axis Label", fontsize=14)  # Customizing the y-axis label

# Customizing ticks and legend
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc="best")  # Position the legend automatically

# Show the plot
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_13952\1400926398.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  # You can choose other styles like 'ggplot', 'fivethirtyeight', etc.

# %%
df_plot = df_res.iloc[11:20,1:].set_index("Zweckbestimmung").T.copy()
# Setting a larger figure size and applying a style
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
plt.style.use('seaborn-darkgrid')  # You can choose other styles like 'ggplot', 'fivethirtyeight', etc.

# Plotting the DataFrame
df_plot.plot(ax=plt.gca())  # Use the current Axes to apply size and style
plt.title("My Fancy Plot", fontsize=16, fontweight='bold')  # Adding a title
plt.xlabel("X-axis Label", fontsize=14)  # Customizing the x-axis label
plt.ylabel("Y-axis Label", fontsize=14)  # Customizing the y-axis label

# Customizing ticks and legend
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=8, loc="best")  # Position the legend automatically

# Show the plot
plt.show()
df_plot.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df_plot = df_res.iloc[11:20,1:].set_index("Zweckbestimmung").T.copy()
#       2 # Setting a larger figure size and applying a style
#       3 plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
#
# NameError: name 'df_res' is not defined

# %%
df_plot = df_res.iloc[20:30,1:].set_index("Zweckbestimmung").T.copy()
# Setting a larger figure size and applying a style
plt.figure(figsize=(12, 8))  # Adjust the width and height as needed
plt.style.use('seaborn-darkgrid')  # You can choose other styles like 'ggplot', 'fivethirtyeight', etc.

# Plotting the DataFrame
df_plot.plot(ax=plt.gca())  # Use the current Axes to apply size and style
plt.title("My Fancy Plot", fontsize=16, fontweight='bold')  # Adding a title
plt.xlabel("X-axis Label", fontsize=14)  # Customizing the x-axis label
plt.ylabel("Y-axis Label", fontsize=14)  # Customizing the y-axis label

# Customizing ticks and legend
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc="best")  # Position the legend automatically

# Show the plot
plt.show()
df_plot.T
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_13952\970360921.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  # You can choose other styles like 'ggplot', 'fivethirtyeight', etc.
#                                                         Ist 2012  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.443339e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.560636e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.310871e+09
# Branntweinsteuer                                    2.121386e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  4.301396e+07
# DFG - Laufende Zwecke                               9.824220e+08
# Solidaritätszuschlag zu den nicht veranlagten S...  1.037035e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.444140e+07
# Gewinne aus Unternehmen und Beteiligungen           1.063455e+09
# BAföG - Zuschüsse an Studierende                    7.989161e+08
#
#                                                         Ist 2013  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.530316e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.903779e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.343151e+09
# Branntweinsteuer                                    2.102421e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  1.360465e+07
# DFG - Laufende Zwecke                               1.031543e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  9.109145e+08
# Einnahmen aus der Ausgabe von Wertmarken für di...  9.774950e+06
# Gewinne aus Unternehmen und Beteiligungen           1.029987e+09
# BAföG - Zuschüsse an Studierende                    7.923961e+08
#
#                                                         Ist 2014  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.645496e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.816630e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.384291e+09
# Branntweinsteuer                                    2.059656e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  2.016479e+07
# DFG - Laufende Zwecke                               1.083178e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  8.775783e+08
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.736281e+09
# Gewinne aus Unternehmen und Beteiligungen           5.824996e+08
# BAföG - Zuschüsse an Studierende                    7.630340e+08
#
#                                                         Ist 2015  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.793155e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.712277e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.403466e+09
# Branntweinsteuer                                    2.069929e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  1.779751e+07
# DFG - Laufende Zwecke                               1.137082e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  9.311464e+08
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.764158e+09
# Gewinne aus Unternehmen und Beteiligungen           1.982438e+08
# BAföG - Zuschüsse an Studierende                    1.138509e+09
#
#                                                         Ist 2016  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.849586e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.265000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.470943e+09
# Branntweinsteuer                                    2.070231e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  5.679460e+07
# DFG - Laufende Zwecke                               1.193160e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.006601e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.823278e+09
# Gewinne aus Unternehmen und Beteiligungen           2.187696e+08
# BAföG - Zuschüsse an Studierende                    1.071350e+09
#
#                                                         Ist 2017  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               1.949246e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.265000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.532645e+09
# Branntweinsteuer                                    2.093589e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  1.350004e+08
# DFG - Laufende Zwecke                               1.254777e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.015984e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.886428e+09
# Gewinne aus Unternehmen und Beteiligungen           2.909306e+08
# BAföG - Zuschüsse an Studierende                    1.143426e+09
#
#                                                         Ist 2018  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               2.010320e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.465000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.611648e+09
# Branntweinsteuer                                    2.132679e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  1.184222e+08
# DFG - Laufende Zwecke                               1.316612e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.189273e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.916957e+09
# Gewinne aus Unternehmen und Beteiligungen           5.767884e+08
# BAföG - Zuschüsse an Studierende                    1.031134e+09
#
#                                                         Ist 2019  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               2.063034e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.355000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.711576e+09
# Branntweinsteuer                                    2.117756e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  1.118618e+08
# DFG - Laufende Zwecke                               1.381398e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.242050e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.960691e+09
# Gewinne aus Unternehmen und Beteiligungen           6.139224e+08
# BAföG - Zuschüsse an Studierende                    9.896008e+08
#
#                                                         Ist 2020  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               2.192763e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.360000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.837218e+09
# Branntweinsteuer                                    2.237900e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  2.074604e+08
# DFG - Laufende Zwecke                               1.447480e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.122193e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.997736e+09
# Gewinne aus Unternehmen und Beteiligungen           1.460390e+09
# BAföG - Zuschüsse an Studierende                    1.106808e+09
#
#                                                         Ist 2021  \
# Zweckbestimmung
# HGF-Zentren - Betrieb                               2.207249e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.325530e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  1.953884e+09
# Branntweinsteuer                                    2.089038e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  2.038063e+08
# DFG - Laufende Zwecke                               1.929402e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.453765e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.661781e+09
# Gewinne aus Unternehmen und Beteiligungen           2.434473e+09
# BAföG - Zuschüsse an Studierende                    1.187060e+09
#
#                                                         Ist 2022      Ist 2023
# Zweckbestimmung
# HGF-Zentren - Betrieb                               2.341454e+09  2.412682e+09
# Abführung der Bundesanstalt für Immobilienaufgaben  2.342690e+09  2.337000e+09
# Bezüge und Nebenleistungen der planmäßigen Beam...  2.029157e+09  2.221172e+09
# Branntweinsteuer                                    2.191282e+09  2.158963e+09
# Zinseinnahmen aus der Anlage von Kassenmitteln ...  4.316888e+08  2.054391e+09
# DFG - Laufende Zwecke                               1.983378e+09  2.038971e+09
# Solidaritätszuschlag zu den nicht veranlagten S...  1.783771e+09  1.977113e+09
# Einnahmen aus der Ausgabe von Wertmarken für di...  1.661498e+09  1.713997e+09
# Gewinne aus Unternehmen und Beteiligungen           2.579599e+09  1.678402e+09
# BAföG - Zuschüsse an Studierende                    1.288607e+09  1.564410e+09

# %%
#

# %%
print("2012")
print("Administrative costs in billion:", df_test[df_test['Zweckbestimmung'].str.contains("Verwaltung")]["Ist 2012"].sum() / 1e9)
df_test[df_test['Zweckbestimmung'].str.contains("Verwaltung")].sort_values("Ist 2012", ascending=False)
# Out:
# 2012
# Administrative costs in billion: 11.32468303503
#           Ist 2012                                    Zweckbestimmung  \
# 4470  5.104600e+09  Erstattungen von Verwaltungsausgaben des Bunde...
# 3675  4.209093e+09  Verwaltungskosten für die Durchführung der Gru...
# 4800  4.642185e+08    Nicht aufteilbare sächliche Verwaltungsausgaben
# 4906  3.001170e+08   Erstattung von Verwaltungsausgaben an die Länder
# 2134  1.926264e+08  Erstattung von Verwaltungskosten an die Bundes...
# ...            ...                                                ...
# 2573  2.164360e+03                     Vermischte Verwaltungsausgaben
# 5621  1.793070e+03    Nicht aufteilbare sächliche Verwaltungsausgaben
# 3406  1.564230e+03    Nicht aufteilbare sächliche Verwaltungsausgaben
# 68    1.211650e+03                     Vermischte Verwaltungsausgaben
# 1020  1.099070e+03  Erwerb von Geräten, Ausstattungs- und Ausrüstu...
#
#              id
# 4470  634011222
# 3675  636131112
# 4800  547811403
# 4906  632011412
# 2134  636010803
# ...         ...
# 2573  539590913
# 5621  547411607
# 3406  547111101
# 68    539990104
# 1020  812020607
#
# [318 rows x 3 columns]

# %%
print("2022")
print("Administrative costs in billion:", df_test_2[df_test_2['Zweckbestimmung'].str.contains("Verwaltung")]["Ist 2022"].sum() / 1e9)
df_test_2[df_test_2['Zweckbestimmung'].str.contains("Verwaltung")].sort_values("Ist 2022", ascending=False)
# Out:
# 2022
# Administrative costs in billion: 17.79898104593
#       Epl.  Kap.   Tit.      Ist 2022  \
# 2581    11     1  63613  6.007084e+09
# 3266    12    16  63401  5.045810e+09
# 2904    12     1  68212  2.112356e+09
# 817      6     2  53238  9.698166e+08
# 3743    14     8  63201  5.488748e+08
# ...    ...   ...    ...           ...
# 169      2    16  53999  2.449120e+03
# 2155     9    16  54741  2.124640e+03
# 2669    11     6  54741  1.685740e+03
# 3501    12    21  81221  1.480880e+03
# 809      6     2  53929  1.087000e+03
#
#                                         Zweckbestimmung         id
# 2581  Verwaltungskosten für die Durchführung der Gru...  636131101
# 3266  Erstattungen von Verwaltungsausgaben des Bunde...  634011216
# 2904  Ausgaben der "Die Autobahn GmbH des Bundes" fü...  682121201
# 817                          Verwaltungsdigitalisierung  532380602
# 3743   Erstattung von Verwaltungsausgaben an die Länder  632011408
# ...                                                 ...        ...
# 169                      Vermischte Verwaltungsausgaben  539990216
# 2155    Nicht aufteilbare sächliche Verwaltungsausgaben  547410916
# 2669    Nicht aufteilbare sächliche Verwaltungsausgaben  547411106
# 3501  Erwerb von Geräten, Ausstattungs- und Ausrüstu...  812211221
# 809                      Vermischte Verwaltungsausgaben  539290602
#
# [450 rows x 6 columns]

# %%
df_test[df_test['Zweckbestimmung'] == "Vermischte Verwaltungsausgaben"].sort_values("Ist 2012", ascending=False)
# Out:
#          Ist 2012                 Zweckbestimmung         id
# 4825  17271418.99  Vermischte Verwaltungsausgaben  539991404
# 2178   7974370.07  Vermischte Verwaltungsausgaben  539990804
# 4768   6693597.81  Vermischte Verwaltungsausgaben  539991403
# 1423   6139311.45  Vermischte Verwaltungsausgaben  539990625
# 1273   2524950.28  Vermischte Verwaltungsausgaben  539290616
# ...           ...                             ...        ...
# 548       2388.36  Vermischte Verwaltungsausgaben  539990407
# 4457      2356.20  Vermischte Verwaltungsausgaben  539191221
# 189       2171.78  Vermischte Verwaltungsausgaben  539990203
# 2573      2164.36  Vermischte Verwaltungsausgaben  539590913
# 68        1211.65  Vermischte Verwaltungsausgaben  539990104
#
# [119 rows x 3 columns]

# %%
df_test_2[df_test_2['Zweckbestimmung'] == "Vermischte Verwaltungsausgaben"].sort_values("Ist 2022", ascending=False)
# Out:
#          Ist 2022                 Zweckbestimmung         id
# 4488  30487202.68  Vermischte Verwaltungsausgaben  539991403
# 4731  25568792.56  Vermischte Verwaltungsausgaben  539991413
# 2220  17270812.00  Vermischte Verwaltungsausgaben  539990813
# 1674   9620942.24  Vermischte Verwaltungsausgaben  539090629
# 4495   7401627.67  Vermischte Verwaltungsausgaben  539191403
# ...           ...                             ...        ...
# 230       8945.01  Vermischte Verwaltungsausgaben  539990217
# 399       6978.85  Vermischte Verwaltungsausgaben  539990415
# 6420      5555.76  Vermischte Verwaltungsausgaben  539293012
# 216       2449.12  Vermischte Verwaltungsausgaben  539990216
# 1063      1087.00  Vermischte Verwaltungsausgaben  539290602
#
# [137 rows x 3 columns]
